# %%
import matplotlib.pyplot as plt

# %%
K=1
pop= .2
pops=[]
r = 1.9

for i in range(100):
	pops.append(pop)
	deltap=r*pop*(1-pop/K)
	pop+=deltap
plt.plot(pops,'go')
plt.plot(pops,'r')
plt.ylabel("Population")
plt.xlabel("Time")
# plt.show()
K=1
pop= .9
pops=[]
r = 2.6

for i in range(100):
	pops.append(pop)
	deltap=r*pop*(1-pop/K)
	pop+=deltap
plt.plot(pops,'go')
plt.plot(pops,'b')
plt.ylabel("Population")
plt.xlabel("Time")
plt.show()

# %% [markdown]
# ### Systsem become chaotic
# When human population reach at chaotic region
#
# The thing with the chaotic region is it is very essential to know the inital conditions because in chaotic regiom the noise scales as exponential. Therefore the tiny noise in the position can leads to completely different paths in the fraction of the seconds.

# %%
#1970 phd done Mike

# %% [markdown]
# ### Complicated dynamics
# # SIR
# ### Description of the SIR model implemented
#
# This code implements a simple **SIR (Susceptible-Infected-Recovered) model** for simulating the spread of an infectious disease in a closed population over 20 days.
#
# - **Model parameters:**
#   - `alpha`: transmission rate (per person per day)
#   - `gamma`: recovery rate (per day)
#   - Initial conditions:
#     - Susceptible (`S = 762`)
#     - Infected (`I = 1`)
#     - Recovered (`R = 0`)
#
# - **Dynamics:**
#   - At each time step (1 day), the number of individuals in each compartment is updated using:
#     - ΔS = -α S I
#     - ΔI = α S I - γ I
#     - ΔR = γ I
#
# - **Visualization:**
#   - The history of S, I, and R is plotted over time:
#     - Susceptible (blue)
#     - Infected (red)
#     - Recovered (green)
#
# This is a **discrete-time approximation** of the classic continuous SIR model and provides insight into the epidemic dynamics.

# %%
import matplotlib.pyplot as plt
alpha=0.00218 #(person-1 day-1)
gamma=0.88    #(day-1)
S=762
I=1
R=0
S_hist=[]
I_hist=[]
R_hist=[]
for day in range(20):
    S_hist.append(S)
    I_hist.append(I)
    R_hist.append(R)
    delta_S=(-alpha*S*I)
    delta_I=alpha*S*I-gamma*I
    delta_R=gamma*I
    S+=delta_S
    I+=delta_I
    R+=delta_R
    S=max(S,0)
    I=max(I,0)
    R=max(R,0)
#Plot S,I,R vs day
plt.plot(S_hist)
plt.plot(I_hist,color='red')
plt.plot(R_hist,color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
alpha=0.00218 #(person-1 day-1)
gamma=0.38    #(day-1)
S=762
I=1
R=0
S_hist=[]
I_hist=[]
R_hist=[]
for day in range(20):
    S_hist.append(S)
    I_hist.append(I)
    R_hist.append(R)
    delta_S=(-alpha*S*I)
    delta_I=alpha*S*I-gamma*I
    delta_R=gamma*I
    S+=delta_S
    I+=delta_I
    R+=delta_R
    S=max(S,0)
    I=max(I,0)
    R=max(R,0)
#Plot S,I,R vs day
plt.plot(S_hist)
plt.plot(I_hist,color='red')
plt.plot(R_hist,color='green')
plt.show()
